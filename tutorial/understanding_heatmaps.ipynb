# %% [markdown]
# Using this tutorial to understand how to plot heatmaps in Python for usage in the Rayleigh Scattering extension, where I intend to aggregate the data of the (x, y) coordinates as the vector space and the colour values of the wavelengths of light being the "heat" displayed. There may be a low density (therefore low resolution) of wavelengths (since school laptop) so learning ways of trying to make their effect larger, and colour mixing into other points would be useful - albeit too late for this type of experimentation.
