# %% [markdown]
# Inspired by a 3Blue1Brown video, I will visualise the intuition between Snell's Law of Refraction and the Brachistochrone curve.
#
# Depending on how much time left, I will simply just solve the problem by hand and explain this in the write-up.
#
# This is the video: https://youtu.be/Cld0p3a43fU?si=VMDwhQP9BmyKsPga

# %% [markdown]
# ## Pseudocode
# Extending from Task 4, I would like to develop a model that have an n-number of layers that can be changed by a slider. Given that the figsize will be constant, I can just subdivide the ranges of each of the refractive indices (which can be stepped up in a uniform manner through the range of the minimum to the maximum) and see at which point each of the lines change their angles in response to this.
#
# One issue is that I don't know how to write algorithms like this - that aren't entirely hardcoded but the code itself is dependent on the input.
#
# For example, if layers = 2 (the minimum) then it is just the base code and I would have to solve two angles: the incident, and refracted. After which, I can plot them pretty simply. If layers = 5, this is more but just layered. How can I do this for n-layers?
#
# Once I have solved that, I will refer back to the video to help with the derivation of the cycloid solution that I will overlay on all plots as the interactive diagram can see which layer (obviously the highest) and which incident angle causes the piecewise function (of all the refracted rays) that is most akin to the cycloid equation.
