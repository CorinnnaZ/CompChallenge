# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Sources
# https://en.wikipedia.org/wiki/Rainbow
#  <!-- Will need to understand this fully before progression, potentially finding further sources from this. Problem solving, however, should be the most efficient way of progression-->
# https://isaacphysics.org/questions/prism_deviations_sym
#
# ## Pseudocode
# 1. Understand what rainbows are and how they work through simple practice questions (maybe looking at the Olympiad ones as well)
# 2. Produce a simple model (of something pertaining to this research) in Python (as it is better to work iteratively).
